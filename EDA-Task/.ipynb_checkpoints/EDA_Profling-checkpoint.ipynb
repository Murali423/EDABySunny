# %% [markdown]
# ### EDA Profling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
filepath = r'C:\Users\HP\Documents\EDA\EDA-BySunny\EDABySunny\Dataset\data1\Travel.csv'
df = pd.read_csv(filepath)
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %% [markdown]
# ### Profiling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
#shape of the dataframe
df.shape
# Out:
# (4888, 20)

# %%
#first 5 samples
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
#Last 5 samples
df.tail()
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 4883  Small Business    Male                       3                5.0
# 4884        Salaried    Male                       4                5.0
# 4885        Salaried  Female                       4                4.0
# 4886  Small Business    Male                       3                4.0
# 4887        Salaried    Male                       4                4.0
#
# ...

# %%
# Random 10 samples 
df.sample(10)
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 620       200620          0  35.0     Self Enquiry         1             33.0
# 1803      201803          0  43.0     Self Enquiry         1             13.0
# 1700      201700          0  52.0     Self Enquiry         1              8.0
# 3570      203570          0  51.0     Self Enquiry         3              6.0
# 1736      201736          0  31.0     Self Enquiry         1             29.0
# 3679      203679          0  47.0     Self Enquiry         3              9.0
# 2702      202702          0  52.0     Self Enquiry         1              7.0
# 4583      204583          1  40.0     Self Enquiry         1             13.0
# 1574      201574          0  37.0  Company Invited         1              8.0
# 2427      202427          1   NaN     Self Enquiry         3             22.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %% [markdown]
# __Observation:__ *Here in this dataset the customerid has no impact and no need to analyze anything it is the customerid countinous numbers we can skip the at datatype*

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df1 = df[['ProdTaken', 'Age', 'TypeofContact', 'CityTier',
       'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
       'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
       'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
       'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome']]
df1
# Out:
#       ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0             1  41.0     Self Enquiry         3              6.0
# 1             0  49.0  Company Invited         1             14.0
# 2             1  37.0     Self Enquiry         1              8.0
# 3             0  33.0  Company Invited         1              9.0
# 4             0   NaN     Self Enquiry         1              8.0
# ...         ...   ...              ...       ...              ...
# 4883          1  49.0     Self Enquiry         3              9.0
# 4884          1  28.0  Company Invited         1             31.0
# 4885          1  52.0     Self Enquiry         3             17.0
# 4886          1  19.0     Self Enquiry         3             16.0
# 4887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0           Salaried  Female                       3                3.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ProdTaken                 4888 non-null   int64
#  1   Age                       4662 non-null   float64
#  2   TypeofContact             4863 non-null   object
#  3   CityTier                  4888 non-null   int64
#  4   DurationOfPitch           4637 non-null   float64
#  5   Occupation                4888 non-null   object
#  6   Gender                    4888 non-null   object
#  7   NumberOfPersonVisiting    4888 non-null   int64
#  8   NumberOfFollowups         4843 non-null   float64
#  9   ProductPitched            4888 non-null   object
#  10  PreferredPropertyStar     4862 non-null   float64
#  11  MaritalStatus             4888 non-null   object
#  12  NumberOfTrips             4748 non-null   float64
# ...

# %%
#categorical column
cat_col = [x for x in df1.columns if df1[x].dtype == 'O']
cat_col
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
#numerical Column
num_col = [x for x in df1.columns if df1[x].dtype!='O']
num_col
# Out:
# ['ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %% [markdown]
# ### Finding the Duplicate Values

# %%
duplicate= df1[df1.duplicated()]
duplicate
# Out:
#       ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 1514          0   NaN  Company Invited         1              6.0
# 1518          0  46.0  Company Invited         3             11.0
# 1531          0  38.0  Company Invited         1             35.0
# 1532          0  50.0     Self Enquiry         1             13.0
# 1536          0  36.0  Company Invited         1             17.0
# ...         ...   ...              ...       ...              ...
# 4760          0  36.0     Self Enquiry         1              9.0
# 4788          0  31.0     Self Enquiry         1             14.0
# 4789          0  45.0     Self Enquiry         1             36.0
# 4793          0  61.0     Self Enquiry         3             14.0
# 4811          0  60.0     Self Enquiry         3             10.0
#
#           Occupation   Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 1514  Small Business   Female                       2                3.0
# ...

# %%
df1.duplicated().sum()
# Out:
# 141

# %% [markdown]
# **Travel dataset has 141 duplicate datapoints**

# %% [markdown]
# ### Finding missing Values

# %%
df1.isnull().sum()
# Out:
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 1012

# %% [markdown]
# **Travel dataset has totally 1012 missing datapoints**

# %% [markdown]
# ### Number of Unique parameters

# %%
df1.nunique()
# Out:
# ProdTaken                      2
# Age                           44
# TypeofContact                  2
# CityTier                       3
# DurationOfPitch               34
# Occupation                     4
# Gender                         3
# NumberOfPersonVisiting         5
# NumberOfFollowups              6
# ProductPitched                 5
# PreferredPropertyStar          3
# MaritalStatus                  4
# NumberOfTrips                 12
# Passport                       2
# PitchSatisfactionScore         5
# OwnCar                         2
# NumberOfChildrenVisiting       4
# Designation                    5
# MonthlyIncome               2475
# dtype: int64

# %%
df1['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Fe Male'], dtype=object)

# %% [markdown]
# __Here the Fe Male has the not different Gender we need to remove the space__

# %%
df1['TypeofContact'].unique()
# Out:
# array(['Self Enquiry', 'Company Invited', nan], dtype=object)

# %%
df1['Occupation'].unique()
# Out:
# array(['Salaried', 'Free Lancer', 'Small Business', 'Large Business'],
#       dtype=object)

# %%
cat_col
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
df1['ProductPitched'].unique()
# Out:
# array(['Deluxe', 'Basic', 'Standard', 'Super Deluxe', 'King'],
#       dtype=object)

# %%
df1['MaritalStatus'].unique()
# Out:
# array(['Single', 'Divorced', 'Married', 'Unmarried'], dtype=object)

# %%
df1['Designation'].unique()
# Out:
# array(['Manager', 'Executive', 'Senior Manager', 'AVP', 'VP'],
#       dtype=object)

# %%
num_col
# Out:
# ['ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
df1['Passport'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df1['Gender'] = df1['Gender'].replace('Fe Male','Female')
df1['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# describe the data frame

# %%
df1.describe()
# Out:
#          ProdTaken          Age     CityTier  DurationOfPitch  \
# count  4888.000000  4662.000000  4888.000000      4637.000000
# mean      0.188216    37.622265     1.654255        15.490835
# std       0.390925     9.316387     0.916583         8.519643
# min       0.000000    18.000000     1.000000         5.000000
# 25%       0.000000    31.000000     1.000000         9.000000
# 50%       0.000000    36.000000     1.000000        13.000000
# 75%       0.000000    44.000000     3.000000        20.000000
# max       1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4888.000000        4843.000000            4862.000000
# mean                 2.905074           3.708445               3.581037
# std                  0.724891           1.002509               0.798009
# min                  1.000000           1.000000               3.000000
# ...

# %%
df1.describe().T
# Out:
#                            count          mean          std     min      25%  \
# ProdTaken                 4888.0      0.188216     0.390925     0.0      0.0
# Age                       4662.0     37.622265     9.316387    18.0     31.0
# CityTier                  4888.0      1.654255     0.916583     1.0      1.0
# DurationOfPitch           4637.0     15.490835     8.519643     5.0      9.0
# NumberOfPersonVisiting    4888.0      2.905074     0.724891     1.0      2.0
# NumberOfFollowups         4843.0      3.708445     1.002509     1.0      3.0
# PreferredPropertyStar     4862.0      3.581037     0.798009     3.0      3.0
# NumberOfTrips             4748.0      3.236521     1.849019     1.0      2.0
# Passport                  4888.0      0.290917     0.454232     0.0      0.0
# PitchSatisfactionScore    4888.0      3.078151     1.365792     1.0      2.0
# OwnCar                    4888.0      0.620295     0.485363     0.0      0.0
# ...

# %%
df1.corr()
# Out:
#                           ProdTaken       Age  CityTier  DurationOfPitch  \
# ProdTaken                  1.000000 -0.147254  0.086852         0.078257
# Age                       -0.147254  1.000000 -0.015625        -0.012063
# CityTier                   0.086852 -0.015625  1.000000         0.022703
# DurationOfPitch            0.078257 -0.012063  0.022703         1.000000
# NumberOfPersonVisiting     0.009627  0.011621 -0.001671         0.065141
# NumberOfFollowups          0.112171 -0.002577  0.023652         0.009434
# PreferredPropertyStar      0.099577 -0.010474 -0.009164        -0.006637
# NumberOfTrips              0.018898  0.184905 -0.029709         0.009715
# Passport                   0.260844  0.033399  0.001793         0.033034
# PitchSatisfactionScore     0.051394  0.018510 -0.042160        -0.002880
# OwnCar                    -0.011508  0.048654  0.003817        -0.001626
# NumberOfChildrenVisiting   0.007421  0.007370  0.000672         0.031408
# ...

# %%
df1.cov()
# Out:
#                            ProdTaken           Age    CityTier  \
# ProdTaken                   0.152822     -0.535959    0.031120
# Age                        -0.535959     86.795067   -0.134168
# CityTier                    0.031120     -0.134168    0.840125
# DurationOfPitch             0.260897     -0.944440    0.176544
# NumberOfPersonVisiting      0.002728      0.078126   -0.001110
# NumberOfFollowups           0.043969     -0.024058    0.021716
# PreferredPropertyStar       0.031050     -0.077447   -0.006707
# NumberOfTrips               0.013743      3.158372   -0.050474
# Passport                    0.046318      0.141269    0.000747
# PitchSatisfactionScore      0.027440      0.235235   -0.052778
# OwnCar                     -0.002184      0.220050    0.001698
# NumberOfChildrenVisiting    0.002494      0.058470    0.000529
# MonthlyIncome            -276.097744  23365.183349  255.945958
#
#                           DurationOfPitch  NumberOfPersonVisiting  \
# ...

# %%
df1.skew()
# Out:
# ProdTaken                   1.595763
# Age                         0.382989
# CityTier                    0.736531
# DurationOfPitch             1.752037
# NumberOfPersonVisiting      0.029817
# NumberOfFollowups          -0.372719
# PreferredPropertyStar       0.895545
# NumberOfTrips               1.453884
# Passport                    0.920980
# PitchSatisfactionScore     -0.127726
# OwnCar                     -0.495892
# NumberOfChildrenVisiting    0.272199
# MonthlyIncome               1.949160
# dtype: float64

# %% [markdown]
# ### Graphical Analysis

# %% [markdown]
# #### Univariate Analysis

# %%
cat_col
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
sns.countplot(df1['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# __Observation: From above we can say that Male are traveling more than female__

# %%
sns.countplot(df1['Occupation'])
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %% [markdown]
# __Observation: From the above figure we can say Salaried employes will travel more than other Occupation.We can make good profits from the salaried employees__

# %%
sns.countplot(df1['TypeofContact'])
# Out:
# <AxesSubplot:xlabel='TypeofContact', ylabel='count'>

# %% [markdown]
# __Observation: From above figure we can say that the Most of the contact will be done from self enquiry than company invited.__

# %%
sns.countplot(df1['MaritalStatus'])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# **Observation: Married will travel more than any other category**

# %%
df1['ProductPitched'].unique()
# Out:
# array(['Deluxe', 'Basic', 'Standard', 'Super Deluxe', 'King'],
#       dtype=object)

# %%
sns.countplot(df1['ProductPitched'])
# Out:
# <AxesSubplot:xlabel='ProductPitched', ylabel='count'>

# %% [markdown]
# Observation: Here Most people prefer Basic Productpitch than any other, after basic more will go on deluxe

# %%
df1['Designation'].unique()
# Out:
# array(['Manager', 'Executive', 'Senior Manager', 'AVP', 'VP'],
#       dtype=object)

# %%
sns.countplot(df1['Designation'])
# Out:
# <AxesSubplot:xlabel='Designation', ylabel='count'>

# %% [markdown]
# Observation: The Executives travel more than any other category, Afer Executives Managers will travel more

# %%
num_col
# Out:
# ['ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
sns.histplot(df1['ProdTaken'])
# Out:
# <AxesSubplot:xlabel='ProdTaken', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(df1['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(df1['CityTier'])
# Out:
# <AxesSubplot:xlabel='CityTier', ylabel='count'>

# %% [markdown]
# observation: From above figure CityTire tyre-1 will get more Travel booking

# %%
sns.countplot(df1['Passport'])
# Out:
# <AxesSubplot:xlabel='Passport', ylabel='count'>

# %% [markdown]
# Observation: from this figure we observe that most customer don't have passport

# %%
sns.countplot(df1['OwnCar'])
# Out:
# <AxesSubplot:xlabel='OwnCar', ylabel='count'>

# %% [markdown]
# Observation: Most of customers owns a car.

# %%
sns.countplot(df['PitchSatisfactionScore'])
# Out:
# <AxesSubplot:xlabel='PitchSatisfactionScore', ylabel='count'>

# %%
sns.distplot(df1['MonthlyIncome'])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Density'>

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.figure(figsize=(15,10))
sns.boxplot(df1['MonthlyIncome'])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
df1.corr()
# Out:
#                           ProdTaken       Age  CityTier  DurationOfPitch  \
# ProdTaken                  1.000000 -0.147254  0.086852         0.078257
# Age                       -0.147254  1.000000 -0.015625        -0.012063
# CityTier                   0.086852 -0.015625  1.000000         0.022703
# DurationOfPitch            0.078257 -0.012063  0.022703         1.000000
# NumberOfPersonVisiting     0.009627  0.011621 -0.001671         0.065141
# NumberOfFollowups          0.112171 -0.002577  0.023652         0.009434
# PreferredPropertyStar      0.099577 -0.010474 -0.009164        -0.006637
# NumberOfTrips              0.018898  0.184905 -0.029709         0.009715
# Passport                   0.260844  0.033399  0.001793         0.033034
# PitchSatisfactionScore     0.051394  0.018510 -0.042160        -0.002880
# OwnCar                    -0.011508  0.048654  0.003817        -0.001626
# NumberOfChildrenVisiting   0.007421  0.007370  0.000672         0.031408
# ...

# %%
sns.heatmap(df1.corr(),annot=True,cmap='icefire',linewidths=0.3)
fig=plt.gcf()
fig.set_size_inches(10,10)
plt.title("corr between variable",color='black',size=15)
plt.show()

# %%
sns.pairplot(df1)
