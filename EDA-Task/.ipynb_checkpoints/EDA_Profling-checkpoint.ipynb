# %% [markdown]
# ### EDA Profling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
filepath = r'C:\Users\HP\Documents\EDA\EDA-BySunny\EDABySunny\Dataset\data6\blackFriday_train.csv'
df = pd.read_csv(filepath)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# ### Profiling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
#shape of the dataframe
df.shape
# Out:
# (550068, 12)

# %%
#first 5 samples
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
#Last 5 samples
df.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550063                 NaN                 NaN       368
# ...

# %%
# Random 10 samples 
df.sample(10)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 330454  1002937  P00018042      F  18-25           4             A
# 509084  1000424  P00118142      M  26-35          17             A
# 485853  1002895  P00327242      M  26-35          11             B
# 231066  1005636  P00308342      M  26-35           7             A
# 527675  1003339  P00258742      M  26-35          17             C
# 156009  1000084  P00241642      M  18-25           4             C
# 119331  1000416  P00178942      M  46-50          14             C
# 421707  1004887  P00258242      M  18-25           2             B
# 50396   1001701  P00178142      F  26-35           4             B
# 537265  1004686  P00117242      M  18-25           1             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 330454                         4+               0                  15
# 509084                          3               0                   8
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [markdown]
# __Observation:__ *Here if we observe there are 5 categorical featues which are given by df.info() 'Product_ID,Gender,Age,City_Category,Stay_In_Current_City_Years' if we keenly observe the data columns 'occupation,Marital_status,Product_Category_1,Product_Category_2,Product_Category_3' are also belongs to catagory so we need to convert those feature to object or string* and also here user_id feature is not useful so we can skip that column.

# %%
df['Product_ID'].dtype
# Out:
# dtype('O')

# %%
i2olist = ['Occupation','Marital_Status', 'Product_Category_1','Product_Category_2', 'Product_Category_3']
for i in i2olist:
    df[i]= df[i].apply(str)
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  object
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  object
#  8   Product_Category_1          550068 non-null  object
#  9   Product_Category_2          550068 non-null  object
#  10  Product_Category_3          550068 non-null  object
#  11  Purchase                    550068 non-null  int64
# dtypes: int64(2), object(10)
# memory usage: 50.4+ MB

# %%
#categorical column
cat_col = [x for x in df.columns if df[x].dtype == 'O']
cat_col
# Out:
# ['Product_ID',
#  'Gender',
#  'Age',
#  'Occupation',
#  'City_Category',
#  'Stay_In_Current_City_Years',
#  'Marital_Status',
#  'Product_Category_1',
#  'Product_Category_2',
#  'Product_Category_3']

# %%
#numerical Column
num_col = [x for x in df.columns if df[x].dtype!='O']
num_col
# Out:
# ['User_ID', 'Purchase']

# %% [markdown]
# **Here we can Exclude the User_ID it is just userID**

# %% [markdown]
# ### Finding the Duplicate Values

# %%
duplicate= df[df.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [User_ID, Product_ID, Gender, Age, Occupation, City_Category, Stay_In_Current_City_Years, Marital_Status, Product_Category_1, Product_Category_2, Product_Category_3, Purchase]
# Index: []

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **From above duplicate variable we can observe that *no row has duplicated* and from manual obersvation no column has duplicated**

# %% [markdown]
# ### Finding missing Values

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64
